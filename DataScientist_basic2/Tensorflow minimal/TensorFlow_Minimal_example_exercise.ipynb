# %% [markdown]
# # TensorFlow 2.0

# %% [markdown]
# ## 課題
#     1. データの数を100,000にしてみましょう
#     2. 学習率を変えてみましょう.
#     3. 損失関数をHuber lossに変えてみましょう
#     huber lossを適用するための文法は'huber_loss'です。
#
# ## 解答
#
# 今回はそれぞれの値を変更するだけですので、解答を記載したコードは作成しません。

# %% [markdown]
# ## ライブラリのインポート

# %%
# We must always import the relevant libraries for our problem at hand. NumPy and TensorFlow are required for this example.
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# ## データの作成

# %%
# データの数を宣言します
observations = 100000

# uniformメソッドを使ってランダムなデータを作成します
xs = np.random.uniform(low=-10, high=10, size=(observations,1))
zs = np.random.uniform(-10, 10, (observations,1))

# column_stackを使って二つのベクトルを行列にします
generated_inputs = np.column_stack((xs,zs))

# ノイズを足します
noise = np.random.uniform(-1, 1, (observations,1))

# Produce the targets according to our f(x,z) = 2x - 3z + 5 + noise definition.
# In this way, we are basically saying: the weights should be 2 and -3, while the bias is 5.
generated_targets = 2*xs - 3*zs + 5 + noise

# save into an npz file called "TF_intro"
np.savez('TF_intro', inputs=generated_inputs, targets=generated_targets)

# %% [markdown]
# ## TensorFlowを用いたコードの作成

# %%
# NPZ形式のファイルの読み込み
training_data = np.load('TF_intro.npz')

# %%
# 入力のサイズの定義
input_size = 2
# 出力のサイズの定義
output_size = 1

# モデルの作成
model = tf.keras.Sequential([
                            # 'Dense'メソッドで線形結合を行っていきます
                            tf.keras.layers.Dense(output_size,
                                                 kernel_initializer=tf.random_uniform_initializer(minval=-0.1, maxval=0.1),
                                                 bias_initializer=tf.random_uniform_initializer(minval=-0.1, maxval=0.1)
                                                 )
                            ])

# 今回はcustom optimizerを使って学習率を0.2に設定します
custom_optimizer = tf.keras.optimizers.SGD(learning_rate=0.2)

# 'compile'で最適化アルゴリズムと損失関数を指定していきます
model.compile(optimizer=custom_optimizer, loss='huber_loss')

# データをモデルにフィットさせていきます
model.fit(training_data['inputs'], training_data['targets'], epochs=100, verbose=2)
# Out:
# Train on 100000 samples
# Epoch 1/100
# 100000/100000 - 3s - loss: 1.9906
# Epoch 2/100
# 100000/100000 - 3s - loss: 1.9765
# Epoch 3/100
# 100000/100000 - 3s - loss: 1.9650
# Epoch 4/100
# 100000/100000 - 3s - loss: 1.9679
# Epoch 5/100
# 100000/100000 - 3s - loss: 1.9697
# Epoch 6/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-ce45845772e0> in <module>
#      20
#      21 # データをモデルにフィットさせていきます
# ---> 22 model.fit(training_data['inputs'], training_data['targets'], epochs=100, verbose=2)
#
# ~/opt/anaconda3/envs/py3-TF2.0/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# ~/opt/anaconda3/envs/py3-TF2.0/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# ~/opt/anaconda3/envs/py3-TF2.0/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     179             batch_end=step * batch_size + current_batch_size)
#     180       cbks.make_logs(model, batch_logs, batch_outs, mode)
# --> 181       step += 1
#     182
#     183     if callbacks.model.stop_training:
#
# ~/opt/anaconda3/envs/py3-TF2.0/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      86         if type is None:
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#      90                 return False
#
# ~/opt/anaconda3/envs/py3-TF2.0/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_v2.py in on_batch(self, step, mode, size)
#     786         if not batch_logs.pop('data_exhausted', False):
#     787           self.callbacks._call_batch_hook(
# --> 788               mode, 'end', step, batch_logs)
#     789           self.progbar.on_batch_end(step, batch_logs)
#
# ~/opt/anaconda3/envs/py3-TF2.0/lib/python3.6/site-packages/tensorflow_core/python/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     240     self._delta_ts[hook_name].append(time.time() - t_before_callbacks)
#     241
# --> 242     delta_t_median = np.median(self._delta_ts[hook_name])
#     243     if (self._delta_t_batch > 0. and
#     244         delta_t_median > 0.95 * self._delta_t_batch and delta_t_median > 0.1):
#
# <__array_function__ internals> in median(*args, **kwargs)
#
# ~/opt/anaconda3/envs/py3-TF2.0/lib/python3.6/site-packages/numpy/lib/function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3493     """
#    3494     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# -> 3495                     overwrite_input=overwrite_input)
#    3496     if keepdims:
#    3497         return r.reshape(k)
#
# ~/opt/anaconda3/envs/py3-TF2.0/lib/python3.6/site-packages/numpy/lib/function_base.py in _ureduce(a, func, **kwargs)
#    3401         keepdim = (1,) * a.ndim
#    3402
# -> 3403     r = func(a, **kwargs)
#    3404     return r, keepdim
#    3405
#
# ~/opt/anaconda3/envs/py3-TF2.0/lib/python3.6/site-packages/numpy/lib/function_base.py in _median(a, axis, out, overwrite_input)
#    3546     if np.issubdtype(a.dtype, np.inexact) and sz > 0:
#    3547         # warn and return nans like mean would
# -> 3548         rout = mean(part[indexer], axis=axis, out=out)
#    3549         return np.lib.utils._median_nancheck(part, rout, axis, out)
#    3550     else:
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 重みとバイアスの抽出

# %%
# 重みとバイアスを表示します
model.layers[0].get_weights()
# Out:
# [array([[ 1.9776261],
#         [-2.9764102]], dtype=float32), array([4.975083], dtype=float32)]

# %%
# 変数に入れます
weights = model.layers[0].get_weights()[0]
weights
# Out:
# array([[ 1.9776261],
#        [-2.9764102]], dtype=float32)

# %%
# 変数に入れます
bias = model.layers[0].get_weights()[1]
bias
# Out:
# array([4.975083], dtype=float32)

# %% [markdown]
# ## 出力の抽出

# %%
# 入力データに対する予測の値を表示していきます
model.predict_on_batch(training_data['inputs']).round(1)
# Out:
# array([[ -9.8],
#        [  9.9],
#        [ -6. ],
#        [ 17.9],
#        [  4.5],
#        [ 22.8],
#        [  2.5],
#        [-10.9],
#        [ 19.4],
#        [-10. ],
#        [ 34.2],
#        [  6.4],
#        [-26.7],
#        [-27.8],
#        [ -7.8],
#        [ 17.1],
#        [ 27.4],
#        [ 15.3],
#        [-15. ],
#        [-21.2],
#        [  9.4],
#        [-19.3],
#        [ 14.5],
#        [ 26.3],
#        [ 21.9],
#        [ -0.3],
#        [ -7.9],
#        [ 28.2],
#        [  1.7],
#        [-14.2],
#        [ 13.1],
#        [ 11.5],
#        [ -1.2],
#        [ 25.2],
#        [  0.3],
#        [  6.6],
#        [ -6. ],
#        [ 17.6],
#        [ 12.7],
#        [  8.3],
#        [ -7.8],
#        [ 25. ],
#        [ -3.8],
#        [ 10.5],
#        [  8. ],
#        [ 12.3],
#        [ 18.5],
#        [  6.4],
#        [  7.6],
#        [  1.6],
#        [  8.5],
#        [-26.9],
#        [ -8.7],
#        [ 30.6],
#        [ 10. ],
#        [  1.1],
#        [  5.5],
#        [-13.1],
#        [-15.7],
#        [-32.8],
#        [ 12. ],
#        [ -9.9],
#        [  3.4],
#        [-20. ],
#        [-42.4],
#        [-30.8],
#        [-19.3],
#        [ -5.8],
#        [ 25.7],
#        [ 15.6],
#        [ 10.3],
#        [-11.5],
#        [  1.8],
#        [ 16.6],
#        [  4.3],
#        [ 46.6],
#        [ 32.1],
#        [ 27.8],
#        [ 13.9],
#        [ -4.4],
#        [  3. ],
#        [-16.2],
#        [  7.3],
#        [ 26.7],
#        [-18.4],
#        [ 30.3],
#        [ -8.3],
#        [  6.9],
#        [ 10.4],
#        [ 26.1],
#        [ 16.2],
#        [  7.1],
#        [ 18.9],
#        [ -7.8],
#        [  8.3],
#        [ 24.8],
#        [-27.1],
#        [ 22.2],
#        [ 44. ],
#        [ 43.2],
#        [ 28.7],
#        [-18.6],
#        [-28.7],
#        [ -4.2],
#        [  3.9],
#        [ 32.3],
#        [ 33. ],
#        [-24.2],
#        [ 25.3],
#        [  0.6],
#        [  7.1],
#        [ 12.3],
#        [ 11.7],
#        [-15.4],
#        [ 44.1],
#        [ 13.8],
#        [-15.2],
#        [ 30.4],
#        [ 23.2],
#        [  7.8],
#        [  6.3],
#        [-13.6],
#        [ 13.8],
#        [ -4.2],
#        [ 16. ],
#        [ 33.1],
#        [-20. ],
#        [ 14.9],
#        [ -4.1],
#        [ 10.8],
#        [ 16.5],
#        [ 24.1],
#        [ 11.4],
#        [ 21.1],
#        [ 20.9],
#        [  5.2],
#        [ -3.6],
#        [  2.6],
#        [ 46.7],
#        [ 13.3],
#        [ 32.2],
#        [  5.6],
#        [ 14.6],
#        [ -4. ],
#        [ -2.3],
#        [ 32.7],
#        [-28. ],
#        [ 27.7],
#        [-12.2],
#        [ 20.6],
#        [ -2.3],
#        [  0.5],
#        [  4.6],
#        [  9.9],
#        [-35.5],
#        [-10.1],
#        [ 24.6],
#        [-16.9],
#        [  6.1],
#        [-19.7],
#        [-43.5],
#        [ -3.4],
#        [ 18.4],
#        [ 52.8],
#        [ 26.6],
#        [ -6.9],
#        [ -9.3],
#        [ -3.2],
#        [-26.2],
#        [  5. ],
#        [-14.3],
#        [ 10.1],
#        [ 21.2],
#        [ -7.2],
#        [ 21.1],
#        [ 31.2],
#        [-19.7],
#        [ 41.4],
#        [-26.4],
#        [-24.4],
#        [-16.1],
#        [  8.4],
#        [ -2.3],
#        [  9.1],
#        [-12. ],
#        [  4.7],
#        [ 23.2],
#        [ 19.3],
#        [  6.5],
#        [ 28.2],
#        [  1.2],
#        [ 34.3],
#        [  7.1],
#        [ 19.3],
#        [ 25.1],
#        [ -3.8],
#        [-18.4],
#        [-16.4],
#        [-19.4],
#        [ 26.3],
#        [-29.4],
#        [ 37.4],
#        [-11.1],
#        [  3.1],
#        [  1.9],
#        [-13.2],
#        [-13.8],
#        [ 14.2],
#        [-18.6],
#        [ 40.4],
#        [ -4.4],
#        [ -2.6],
#        [  8.5],
#        [ 33.8],
#        [ 15.2],
#        [-11.6],
#        [-10.2],
#        [-40.6],
#        [ 38.4],
#        [-35.4],
#        [-36.3],
#        [ 37.8],
#        [ 21.8],
#        [ 27.5],
#        [ 11.7],
#        [ -7.5],
#        [  2.7],
#        [ -6.7],
#        [ 17.1],
#        [  3.9],
#        [ 20.1],
#        [ 13.2],
#        [  8.1],
#        [-20.6],
#        [ 14.4],
#        [ -1.9],
#        [-10.5],
#        [-12.7],
#        [ -0.3],
#        [ 26.4],
#        [ -6.6],
#        [ 22.2],
#        [ 17.9],
#        [ -1.4],
#        [ 39.6],
#        [ 19.3],
#        [-21. ],
#        [ 18.9],
#        [ 35. ],
#        [ 20.7],
#        [ 16.8],
#        [ 13.6],
#        [ -3.3],
#        [-11.8],
#        [ 27.6],
#        [ 24.6],
#        [ 44.9],
#        [ -6.7],
#        [ 19.4],
#        [ 39.1],
#        [ 21.5],
#        [ -2.7],
#        [ 36.8],
#        [-37.4],
#        [ 19.6],
#        [ 18.7],
#        [ 42.7],
#        [ 34.2],
#        [ 29.9],
#        [  2.4],
#        [ 26.9],
#        [ 15.5],
#        [  5.4],
#        [-10.7],
#        [ 20. ],
#        [  0.1],
#        [  1.4],
#        [ -0.4],
#        [-24.8],
#        [ 40.7],
#        [ -3.6],
#        [ 27.3],
#        [  7.4],
#        [ 17.8],
#        [ -2.9],
#        [-10.3],
#        [ -9.6],
#        [  7.4],
#        [  3.1],
#        [ 18.7],
#        [-25.5],
#        [  3.8],
#        [  0. ],
#        [ 19.8],
#        [ 18.1],
#        [  1. ],
#        [  1.6],
#        [ 22.5],
#        [ 40.7],
#        [ 30.1],
#        [ 22.6],
#        [ 27.4],
#        [  9.5],
#        [  3.1],
#        [-16.7],
#        [ 20.3],
#        [-13.8],
#        [-20.1],
#        [ -1.3],
#        [-16.1],
#        [  8.7],
#        [  4.1],
#        [ -0.4],
#        [ -9.3],
#        [ -5.6],
#        [ 27.8],
#        [  8.8],
#        [ 15.2],
#        [ 26.6],
#        [ 17.4],
#        [ -3.7],
#        [ 33.3],
#        [-10.4],
#        [ 15.7],
#        [  2.6],
#        [ -1.7],
#        [ -4.2],
#        [-19.8],
#        [-21.4],
#        [ 18. ],
#        [ 17.5],
#        [-25.4],
#        [ 30.5],
#        [ 30.9],
#        [ 26.3],
#        [ 11.9],
#        [-24. ],
#        [ 17.8],
#        [ 20.7],
#        [  5.1],
#        [ 37.5],
#        [-10.6],
#        [ 24.1],
#        [ -2.1],
#        [  6. ],
#        [ -0.4],
#        [-37.8],
#        [ 23.7],
#        [ 27.8],
#        [-20.1],
#        [  4.2],
#        [  2.1],
#        [-28.4],
#        [ 12.4],
#        [-26.7],
#        [-13. ],
#        [  5.4],
#        [ 15.7],
#        [  8.4],
#        [ 37.9],
#        [-11.4],
#        [ 17.9],
#        [ 31.9],
#        [ -2.3],
#        [-30.6],
#        [-29. ],
#        [ -7.4],
#        [ 30.6],
#        [  4. ],
#        [ 18.5],
#        [-17.8],
#        [ 38.4],
#        [-38.5],
#        [-17.5],
#        [-11. ],
#        [ 20.8],
#        [ 19.1],
#        [  8.4],
#        [ 36.2],
#        [  7.1],
#        [-13.4],
#        [  3.4],
#        [ -0.5],
#        [-17. ],
#        [ -6.1],
#        [-27.9],
#        [ -1.3],
#        [ 17. ],
#        [ 36.2],
#        [ -1.2],
#        [ -9.6],
#        [ 39.2],
#        [ 40. ],
#        [ 21.9],
#        [ 19.1],
#        [ 41.2],
#        [-19.1],
#        [  4.2],
#        [-12.1],
#        [-21. ],
#        [  6.8],
#        [-14.6],
#        [ -7.5],
#        [ -8.6],
#        [ -4.9],
#        [ -8.2],
#        [ -8.2],
#        [ 23.6],
#        [ 23.9],
#        [-13.2],
#        [  5. ],
#        [-32.1],
#        [-42.1],
#        [ 16. ],
#        [ 19.1],
#        [ 12.4],
#        [ 18.3],
#        [ 25.7],
#        [-25.2],
#        [ -5.2],
#        [ -4. ],
#        [ 34.8],
#        [ 10. ],
#        [-41.9],
#        [-26.3],
#        [-10.1],
#        [  3.7],
#        [ 23.5],
#        [  0. ],
#        [  8.5],
#        [-12.9],
#        [ -6.5],
#        [ 34.7],
#        [ 10.5],
#        [ 10. ],
#        [ 10.2],
#        [ 49.4],
#        [ 19.3],
#        [ 17.6],
#        [ 32.7],
#        [-13.3],
#        [-18.8],
#        [ 10.7],
#        [  5.2],
#        [ 19.6],
#        [ -9.8],
#        [-19.5],
#        [  7.5],
#        [ -1.2],
#        [  5.7],
#        [-19.1],
#        [-10.8],
#        [ 16.8],
#        [ 18.7],
#        [-36.8],
#        [-18.8],
#        [ 34.4],
#        [ 30.5],
#        [ 20.6],
#        [ 11.2],
#        [  2.5],
#        [ 14. ],
#        [ 27.2],
#        [ 19. ],
#        [ 29.2],
#        [ -1.2],
#        [  1.1],
#        [ 43.7],
#        [ -7.2],
#        [ -5.1],
#        [ -3.3],
#        [  6. ],
#        [ 13.9],
#        [-19.6],
#        [  7.9],
#        [-31.7],
#        [ -5.4],
#        [ 19.5],
#        [ 12. ],
#        [ -9.9],
#        [  2.2],
#        [ 39.9],
#        [ 37.9],
#        [-39.1],
#        [ 32.8],
#        [-21.9],
#        [ 31.5],
#        [-26.8],
#        [-28.1],
#        [-37.4],
#        [ 33.2],
#        [  4.4],
#        [ -4.6],
#        [-35.2],
#        [  3.9],
#        [ 33.2],
#        [ 24.1],
#        [ 10.4],
#        [  1.2],
#        [ 13.4],
#        [ 12.7],
#        [-22.4],
#        [  9.8],
#        [  8.2],
#        [-20.2],
#        [-27.2],
#        [-20.2],
#        [ -1.8],
#        [-27.1],
#        [  1.5],
#        [ 16.7],
#        [ 10.1],
#        [ 39. ],
#        [ 16.6],
#        [-27.1],
#        [-35.2],
#        [  7.6],
#        [  7.3],
#        [-21.1],
#        [ 20.2],
#        [ -9.3],
#        [ -2.5],
#        [ 16.2],
#        [ 12.1],
#        [-13.5],
#        [-16.6],
#        [ 38.6],
#        [-13.3],
#        [ 14.8],
#        [ 46.6],
#        [-17.7],
#        [ -2.3],
#        [ 22.5],
#        [ -4.9],
#        [-24.1],
#        [-12.1],
#        [ -9.5],
#        [ 15. ],
#        [ -3.5],
#        [ 17.2],
#        [ 31. ],
#        [-17.5],
#        [ 15.9],
#        [-12.6],
#        [ 31.5],
#        [ 29.9],
#        [ -3.4],
#        [ -1.8],
#        [ -0.2],
#        [ 35.7],
#        [ 42.3],
#        [ 25.5],
#        [ 47.7],
#        [-11.4],
#        [ -4.2],
#        [ 28.5],
#        [ -4.1],
#        [ 22.8],
#        [-19. ],
#        [-15. ],
#        [ 12.3],
#        [ -1.2],
#        [  1.4],
#        [-15.3],
#        [-18.5],
#        [-22.8],
#        [-26.3],
#        [ 33.7],
#        [-18.2],
#        [ 11.3],
#        [ 12.7],
#        [ 30.2],
#        [ 24.1],
#        [ 30.7],
#        [ 18.9],
#        [ 28.9],
#        [-12. ],
#        [-22.6],
#        [ -9.6],
#        [-11.2],
#        [-10.5],
#        [  3.4],
#        [ -3.7],
#        [ 14. ],
#        [ 36.7],
#        [ 12.8],
#        [ 33.2],
#        [  0.1],
#        [-29.9],
#        [ 22.9],
#        [ 38.1],
#        [ 26.5],
#        [ 23.9],
#        [ 14. ],
#        [  7.9],
#        [ 23.1],
#        [ 37.8],
#        [ 42.1],
#        [-29.6],
#        [ 29.2],
#        [ 12.8],
#        [  9.5],
#        [ 11.9],
#        [ -6.4],
#        [ -2.9],
#        [  7.2],
#        [-19.2],
#        [ -2.3],
#        [ 20. ],
#        [ -1.8],
#        [-26.4],
#        [-17.4],
#        [ 25.7],
#        [ 17. ],
#        [ -3.3],
#        [  7. ],
#        [  2.5],
#        [ 12.1],
#        [ 29.9],
#        [  5.8],
#        [ 17.3],
#        [-33.7],
#        [  2.2],
#        [ 30.6],
#        [-17.3],
#        [  2.2],
#        [-29.8],
#        [  4.7],
#        [  3.4],
#        [ -3. ],
#        [  7.7],
#        [ 26.6],
#        [ -4.6],
#        [  0.7],
#        [ 21.2],
#        [  8.1],
#        [ 17.1],
#        [ 41. ],
#        [  4.1],
#        [ -7.3],
#        [ -9.7],
#        [  3.6],
#        [-11.2],
#        [-19.1],
#        [ 19.7],
#        [ 34.4],
#        [-33. ],
#        [ 20.2],
#        [  4.9],
#        [ 25.8],
#        [ 42.3],
#        [ 35.9],
#        [  7.9],
#        [-16.9],
#        [-16.8],
#        [ 21.3],
#        [  6.2],
#        [ -9. ],
#        [  3.3],
#        [ 24.8],
#        [ -4.8],
#        [ -2. ],
#        [ 29.7],
#        [ 18.1],
#        [-24.4],
#        [-38. ],
#        [  7.5],
#        [-11.3],
#        [ -0. ],
#        [-19.4],
#        [ -9.1],
#        [ 30.9],
#        [-15.5],
#        [ 16.6],
#        [ 15. ],
#        [  0.9],
#        [ 36.6],
#        [ -4. ],
#        [ 26.9],
#        [ -0.4],
#        [ 20.7],
#        [ 35.2],
#        [-29.6],
#        [ 20.7],
#        [ -3. ],
#        [ 24.2],
#        [ 16.6],
#        [ 15.9],
#        [-30.5],
#        [-36.7],
#        [ -6. ],
#        [-11.1],
#        [ 13.7],
#        [-15.1],
#        [ -8.4],
#        [ -1.4],
#        [ -5.4],
#        [ 23.1],
#        [ 15. ],
#        [-18.1],
#        [ 13.7],
#        [ 20.1],
#        [-23.4],
#        [ -5.5],
#        [-13.2],
#        [ -6.8],
#        [ 29.3],
#        [ 40.7],
#        [ 34.4],
#        [ 36.9],
#        [ 29. ],
#        [ 47.3],
#        [ 28.8],
#        [ -9.8],
#        [-12.2],
#        [ 32.6],
#        [-20.7],
#        [-18.6],
#        [-28.7],
#        [ 17.7],
#        [  3.5],
#        [  3.8],
#        [  0.2],
#        [ 18.1],
#        [-23.9],
#        [  8.8],
#        [ 32.8],
#        [ 22.3],
#        [ 26.3],
#        [  7.2],
#        [  6. ],
#        [  8.6],
#        [-37.5],
#        [ -8.5],
#        [ 19.5],
#        [ 37.5],
#        [-30.1],
#        [ 14.9],
#        [  3. ],
#        [  7.1],
#        [ 44.3],
#        [ 16.1],
#        [ 20.8],
#        [ 25.6],
#        [  7.5],
#        [-10.4],
#        [  4.1],
#        [ 17.7],
#        [ 30.6],
#        [  2.2],
#        [ -1.7],
#        [ 45.7],
#        [ 27.4],
#        [-26.5],
#        [-11.4],
#        [ -7.4],
#        [ 16.5],
#        [ 30.6],
#        [ -4.8],
#        [-28.8],
#        [ -1.1],
#        [-17.9],
#        [ -3.2],
#        [-32.3],
#        [-17.3],
#        [-10.9],
#        [-10.1],
#        [-18.2],
#        [ 24.4],
#        [  4.8],
#        [-16. ],
#        [-15.2],
#        [ -3.2],
#        [-28. ],
#        [ 12.5],
#        [ -4.9],
#        [ 22.1],
#        [-15.7],
#        [ 21.9],
#        [ 18.9],
#        [  8.8],
#        [ 39.9],
#        [-19.3],
#        [ 34.9],
#        [-35.9],
#        [ 21.3],
#        [-14.1],
#        [  1.2],
#        [  2.4],
#        [ 45.1],
#        [ 42.4],
#        [ 18.2],
#        [-21.4],
#        [ 25.2],
#        [ 18.6],
#        [  9.2],
#        [ 15.1],
#        [ -6.2],
#        [ -2.7],
#        [  5.9],
#        [ 37.5],
#        [ 37.8],
#        [-32.7],
#        [ 20. ],
#        [ 36.6],
#        [-23.2],
#        [ 33.6],
#        [ -8.1],
#        [ 23.6],
#        [ 19.4],
#        [-28.1],
#        [  7.6],
#        [-20.7],
#        [ 23.4],
#        [  5.9],
#        [-16.7],
#        [ 19.9],
#        [-25.4],
#        [-15.6],
#        [ 25.3],
#        [-24.4],
#        [ 25.2],
#        [ 14.1],
#        [ 42.3],
#        [-29.8],
#        [ -2.8],
#        [-21.1],
#        [ 35.8],
#        [ 12.2],
#        [ -5.2],
#        [-12.3],
#        [-15.7],
#        [ 15.2],
#        [  0.4],
#        [ -4.6],
#        [ 23.5],
#        [ 13.7],
#        [ 37.8],
#        [  9.2],
#        [ 24.5],
#        [  6.9],
#        [ 25.6],
#        [  6.9],
#        [ 16.8],
#        [ -4.2],
#        [  2.1],
#        [  1.4],
#        [ 13.5],
#        [ 46.2],
#        [-10.4],
#        [-17.6],
#        [ 32.6],
#        [ -0.8],
#        [-10.8],
#        [ 18.8],
#        [-22.2],
#        [  2.4],
#        [  0.2],
#        [  2. ],
#        [ -5.9],
#        [ 13.8],
#        [ 18.1],
#        [-30.8],
#        [ 17.9],
#        [ 37. ],
#        [  0.8],
#        [ 43.4],
#        [ 13. ],
#        [-19.2],
#        [ 29.8],
#        [ -8.7],
#        [  7.8],
#        [ 37.3],
#        [ 18. ],
#        [-27.3],
#        [  0.2],
#        [  5.6],
#        [ 19.5],
#        [ -3.7],
#        [-38.7],
#        [-30.4],
#        [ 30.1],
#        [ -6.6],
#        [  9.3],
#        [ 26.7],
#        [ 23.3],
#        [  7.7],
#        [  7. ],
#        [-23. ],
#        [ 39.1],
#        [ 42.1],
#        [ 24.4],
#        [ 26. ],
#        [-37.4],
#        [ 16.2],
#        [-15.4],
#        [-18.7],
#        [ 19.4],
#        [ 23.1],
#        [  4.7],
#        [ 13.9],
#        [-20.4],
#        [ 17. ],
#        [ 28.4],
#        [ 31.7],
#        [  8.6],
#        [ -1.5],
#        [ -0.1],
#        [ 33.8],
#        [ 20.6],
#        [ 11.1],
#        [ 30.7],
#        [ -1.8],
#        [ 28.1],
#        [ -9.8],
#        [ 15.8],
#        [ -6. ],
#        [  6.8],
#        [  1.2],
#        [ 33. ],
#        [ 23.1],
#        [-13.3],
#        [ 10.6],
#        [ 11.6],
#        [  5.4],
#        [ -9.7],
#        [ -4.4],
#        [ 26.4],
#        [-12.5],
#        [ 12.6],
#        [ 29. ],
#        [ 44.6],
#        [ 10. ],
#        [ 46. ],
#        [ 15. ],
#        [ -0.4],
#        [ 12.9],
#        [  6.1],
#        [-18.1],
#        [ -8.9],
#        [ 26.7],
#        [ -6.5],
#        [ -1.1],
#        [ 20. ],
#        [ 13.8],
#        [ 14.8],
#        [ 22.2],
#        [ 40.4],
#        [ 17.8],
#        [ 10.1],
#        [  3.6],
#        [ 16.5],
#        [ -7.9],
#        [ -8.7],
#        [ -6.9],
#        [  5.4],
#        [ 36.1],
#        [ 22.8],
#        [ 40.6],
#        [ 34.1],
#        [-11.1],
#        [ 18.9],
#        [ 40.7],
#        [ 35.8],
#        [-12.1],
#        [ -6.7],
#        [ 18.9],
#        [ 35.5],
#        [  8.4],
#        [  9.7],
#        [ 24.7],
#        [  3.1],
#        [ 12.9],
#        [-23.7],
#        [ -4.6],
#        [-30.1],
#        [ 29.8],
#        [ 29.9],
#        [-25. ],
#        [  0.3],
#        [  9.6],
#        [ -7.2],
#        [ 14.9],
#        [  7.6],
#        [ -0.3],
#        [ 16.8],
#        [ -1.6],
#        [-14.4],
#        [ 23. ],
#        [ 10.7],
#        [ 20. ],
#        [ 22.2],
#        [ -3.9],
#        [  8.6],
#        [ 22.2],
#        [  5.4],
#        [ 29.1],
#        [-17.7],
#        [  1.1],
#        [ 39.5]], dtype=float32)

# %%
# ターゲットを表示します
training_data['targets'].round(1)
# Out:
# array([[ -9.8],
#        [  9.5],
#        [ -7. ],
#        [ 17.1],
#        [  3.9],
#        [ 22.5],
#        [  1.7],
#        [-10.1],
#        [ 20. ],
#        [-10.1],
#        [ 34.2],
#        [  5.6],
#        [-28. ],
#        [-28.5],
#        [ -8.4],
#        [ 18.1],
#        [ 28. ],
#        [ 15. ],
#        [-15.4],
#        [-20.9],
#        [  9.1],
#        [-19.5],
#        [ 14.3],
#        [ 27.1],
#        [ 22.1],
#        [ -1.2],
#        [ -8.3],
#        [ 28.4],
#        [  1. ],
#        [-13.5],
#        [ 13.4],
#        [ 11.4],
#        [ -0.3],
#        [ 26. ],
#        [  0.9],
#        [  5.8],
#        [ -5.8],
#        [ 18.1],
#        [ 12.8],
#        [  8.7],
#        [ -7.5],
#        [ 25.6],
#        [ -3.3],
#        [ 11.3],
#        [  7.9],
#        [ 12.5],
#        [ 19.7],
#        [  6.8],
#        [  7.4],
#        [  1.4],
#        [  7.7],
#        [-28.1],
#        [ -7.9],
#        [ 31.7],
#        [ 10.3],
#        [  1.2],
#        [  4.7],
#        [-12.6],
#        [-16.6],
#        [-33.6],
#        [ 11.8],
#        [-10.6],
#        [  3.6],
#        [-19.7],
#        [-43.7],
#        [-31.7],
#        [-19. ],
#        [ -5.8],
#        [ 25.1],
#        [ 16.2],
#        [ 10.7],
#        [-11.7],
#        [  1. ],
#        [ 17.4],
#        [  4.1],
#        [ 46.2],
#        [ 31.6],
#        [ 29.1],
#        [ 13.1],
#        [ -3.8],
#        [  3.2],
#        [-15.8],
#        [  7.6],
#        [ 27.6],
#        [-19.2],
#        [ 30.6],
#        [ -9.1],
#        [  6.3],
#        [ 10.1],
#        [ 27. ],
#        [ 16.9],
#        [  8. ],
#        [ 18.3],
#        [ -7.9],
#        [  8.1],
#        [ 25.6],
#        [-28.2],
#        [ 21.5],
#        [ 45. ],
#        [ 43.9],
#        [ 29.3],
#        [-19.7],
#        [-28. ],
#        [ -3.6],
#        [  3.9],
#        [ 32.3],
#        [ 33.5],
#        [-25. ],
#        [ 25.3],
#        [  0.7],
#        [  7.7],
#        [ 12.3],
#        [ 12.6],
#        [-15.6],
#        [ 44.6],
#        [ 14.7],
#        [-15. ],
#        [ 30.9],
#        [ 24.2],
#        [  8.1],
#        [  6.6],
#        [-13.9],
#        [ 13.7],
#        [ -4.4],
#        [ 16.3],
#        [ 33.8],
#        [-20.9],
#        [ 15.5],
#        [ -5. ],
#        [ 10.2],
#        [ 16. ],
#        [ 24.6],
#        [ 11.9],
#        [ 21.1],
#        [ 21.7],
#        [  5.2],
#        [ -3.1],
#        [  1.6],
#        [ 46.2],
#        [ 13. ],
#        [ 31.7],
#        [  5.6],
#        [ 15.5],
#        [ -4.7],
#        [ -1.8],
#        [ 32.9],
#        [-29. ],
#        [ 27.2],
#        [-12.8],
#        [ 20.2],
#        [ -1.3],
#        [  1.2],
#        [  3.7],
#        [  9. ],
#        [-35.4],
#        [-10.2],
#        [ 25.1],
#        [-17.5],
#        [  6. ],
#        [-19.3],
#        [-44.2],
#        [ -3. ],
#        [ 17.6],
#        [ 53. ],
#        [ 26.6],
#        [ -7.7],
#        [ -9.8],
#        [ -2.8],
#        [-26.1],
#        [  4.7],
#        [-14.3],
#        [ 10.3],
#        [ 22.1],
#        [ -6.8],
#        [ 21.6],
#        [ 30.7],
#        [-20.8],
#        [ 42.7],
#        [-26.7],
#        [-25.2],
#        [-16. ],
#        [  8. ],
#        [ -2.5],
#        [  8.8],
#        [-11.8],
#        [  4.5],
#        [ 24. ],
#        [ 18.7],
#        [  6.6],
#        [ 29.1],
#        [  1.8],
#        [ 35.2],
#        [  7.4],
#        [ 20.1],
#        [ 24.4],
#        [ -3.3],
#        [-19.5],
#        [-16. ],
#        [-20. ],
#        [ 27. ],
#        [-30.4],
#        [ 37.1],
#        [-10.5],
#        [  2.3],
#        [  2.4],
#        [-13. ],
#        [-13.9],
#        [ 14.4],
#        [-17.9],
#        [ 40.4],
#        [ -3.7],
#        [ -3. ],
#        [  9.5],
#        [ 33.2],
#        [ 14.4],
#        [-12.7],
#        [-11.3],
#        [-41.6],
#        [ 39.3],
#        [-35.9],
#        [-36. ],
#        [ 38.4],
#        [ 22.3],
#        [ 27.2],
#        [ 11.1],
#        [ -8.4],
#        [  1.7],
#        [ -6. ],
#        [ 17.4],
#        [  3.7],
#        [ 20.7],
#        [ 12.7],
#        [  7.9],
#        [-20.4],
#        [ 14.7],
#        [ -2.9],
#        [-10.4],
#        [-13.4],
#        [ -1.3],
#        [ 26.5],
#        [ -6.8],
#        [ 23.3],
#        [ 17.7],
#        [ -2.4],
#        [ 39.5],
#        [ 19.8],
#        [-21.7],
#        [ 19.7],
#        [ 34.3],
#        [ 20.1],
#        [ 17. ],
#        [ 14. ],
#        [ -4.2],
#        [-11.4],
#        [ 27.3],
#        [ 24. ],
#        [ 45.8],
#        [ -5.9],
#        [ 20.4],
#        [ 39.3],
#        [ 21.3],
#        [ -2.2],
#        [ 37.7],
#        [-38.2],
#        [ 19.7],
#        [ 18.6],
#        [ 42.4],
#        [ 34. ],
#        [ 30.9],
#        [  2.6],
#        [ 27.4],
#        [ 15.2],
#        [  5.3],
#        [-11.4],
#        [ 20. ],
#        [  0.6],
#        [  1. ],
#        [ -0.5],
#        [-25.1],
#        [ 41.8],
#        [ -4.3],
#        [ 26.9],
#        [  7.6],
#        [ 17.4],
#        [ -3.2],
#        [ -9.6],
#        [ -9.5],
#        [  6.7],
#        [  3. ],
#        [ 19.6],
#        [-26.7],
#        [  2.8],
#        [ -0.8],
#        [ 20.3],
#        [ 17.6],
#        [  1.1],
#        [  1.2],
#        [ 23.2],
#        [ 41.2],
#        [ 29.7],
#        [ 22.2],
#        [ 27.6],
#        [  9. ],
#        [  3.1],
#        [-17.1],
#        [ 20.4],
#        [-13.8],
#        [-19.8],
#        [ -1.7],
#        [-15.9],
#        [  8.1],
#        [  3.5],
#        [ -0.4],
#        [ -9.2],
#        [ -5.8],
#        [ 27.3],
#        [  9.5],
#        [ 15. ],
#        [ 26.7],
#        [ 18.6],
#        [ -3.2],
#        [ 32.9],
#        [-10.3],
#        [ 16.2],
#        [  3.4],
#        [ -1.8],
#        [ -4.4],
#        [-20.8],
#        [-21.2],
#        [ 17.9],
#        [ 17. ],
#        [-26.3],
#        [ 30.2],
#        [ 31.1],
#        [ 27.2],
#        [ 12. ],
#        [-24. ],
#        [ 18.5],
#        [ 20. ],
#        [  5.1],
#        [ 37.7],
#        [-10.3],
#        [ 24.4],
#        [ -2.2],
#        [  5.6],
#        [ -0.5],
#        [-37.3],
#        [ 23.7],
#        [ 28.4],
#        [-20.8],
#        [  3.3],
#        [  2.4],
#        [-28. ],
#        [ 13.3],
#        [-27.8],
#        [-12.7],
#        [  5.6],
#        [ 16. ],
#        [  9.3],
#        [ 38.6],
#        [-10.9],
#        [ 17.9],
#        [ 32. ],
#        [ -3.1],
#        [-30.7],
#        [-30.2],
#        [ -8. ],
#        [ 31.7],
#        [  4.7],
#        [ 18.3],
#        [-18.8],
#        [ 38.8],
#        [-38.3],
#        [-16.7],
#        [-11.9],
#        [ 21.8],
#        [ 18.3],
#        [  7.7],
#        [ 35.8],
#        [  7.3],
#        [-13.7],
#        [  3.7],
#        [ -0.2],
#        [-17. ],
#        [ -5.5],
#        [-28.6],
#        [ -1.9],
#        [ 18. ],
#        [ 36.6],
#        [ -1.4],
#        [ -9.3],
#        [ 40.1],
#        [ 39.8],
#        [ 21.3],
#        [ 18.5],
#        [ 42.3],
#        [-19.8],
#        [  4.2],
#        [-12.6],
#        [-21.9],
#        [  7.8],
#        [-15.5],
#        [ -8.3],
#        [ -8.2],
#        [ -6. ],
#        [ -8.4],
#        [ -8.4],
#        [ 24. ],
#        [ 24.3],
#        [-12.3],
#        [  6. ],
#        [-31.5],
#        [-42.6],
#        [ 16.6],
#        [ 18.3],
#        [ 13.1],
#        [ 18.4],
#        [ 26.8],
#        [-25.5],
#        [ -5.5],
#        [ -3.3],
#        [ 34.2],
#        [ 10.7],
#        [-41.4],
#        [-26.2],
#        [ -9.6],
#        [  3.2],
#        [ 24.3],
#        [  0.5],
#        [  8.7],
#        [-12.1],
#        [ -7.1],
#        [ 34.6],
#        [ 10.7],
#        [ 10.2],
#        [ 10.2],
#        [ 48.8],
#        [ 19.1],
#        [ 17. ],
#        [ 32.4],
#        [-13.1],
#        [-19.5],
#        [ 11. ],
#        [  5.7],
#        [ 19.7],
#        [ -9.5],
#        [-20.5],
#        [  7.8],
#        [ -0.5],
#        [  6.7],
#        [-18.3],
#        [-10. ],
#        [ 17.1],
#        [ 19.6],
#        [-38.1],
#        [-19. ],
#        [ 34.9],
#        [ 30.6],
#        [ 21.5],
#        [ 12.2],
#        [  1.9],
#        [ 13.8],
#        [ 27.2],
#        [ 19.5],
#        [ 28.8],
#        [ -1.9],
#        [  1.2],
#        [ 44.1],
#        [ -8. ],
#        [ -4.6],
#        [ -3.3],
#        [  5.8],
#        [ 14.9],
#        [-19.7],
#        [  7.4],
#        [-31.3],
#        [ -4.9],
#        [ 19. ],
#        [ 11.7],
#        [ -9.4],
#        [  3. ],
#        [ 39.7],
#        [ 37.3],
#        [-40.2],
#        [ 32.6],
#        [-21.4],
#        [ 31.5],
#        [-26.1],
#        [-27.7],
#        [-38.4],
#        [ 32.7],
#        [  4.9],
#        [ -4.3],
#        [-35.6],
#        [  3.7],
#        [ 34.5],
#        [ 23.4],
#        [ 11.2],
#        [  1. ],
#        [ 14.2],
#        [ 13.2],
#        [-21.8],
#        [  9.2],
#        [  7.4],
#        [-19.8],
#        [-27.5],
#        [-20.1],
#        [ -1. ],
#        [-27.4],
#        [  1.8],
#        [ 16.3],
#        [ 10.2],
#        [ 38.6],
#        [ 17.1],
#        [-27.2],
#        [-35. ],
#        [  6.9],
#        [  7.6],
#        [-21.5],
#        [ 20.1],
#        [ -8.5],
#        [ -2.2],
#        [ 15.9],
#        [ 13. ],
#        [-14.5],
#        [-16.2],
#        [ 38. ],
#        [-13.7],
#        [ 14.1],
#        [ 47.7],
#        [-18.3],
#        [ -1.5],
#        [ 22.9],
#        [ -4.5],
#        [-23.9],
#        [-11.3],
#        [ -8.7],
#        [ 14.9],
#        [ -2.6],
#        [ 17.9],
#        [ 31.7],
#        [-17.6],
#        [ 15.7],
#        [-12. ],
#        [ 30.9],
#        [ 31. ],
#        [ -3.9],
#        [ -1.1],
#        [ -1. ],
#        [ 36.2],
#        [ 41.9],
#        [ 25.4],
#        [ 48.5],
#        [-11.7],
#        [ -4.9],
#        [ 28.9],
#        [ -3.9],
#        [ 22.9],
#        [-19.6],
#        [-15.5],
#        [ 13.1],
#        [ -1.6],
#        [  1.7],
#        [-14.6],
#        [-18.5],
#        [-22.5],
#        [-25.9],
#        [ 34.5],
#        [-18. ],
#        [ 10.4],
#        [ 12.4],
#        [ 29.8],
#        [ 24.2],
#        [ 31. ],
#        [ 19.5],
#        [ 30.1],
#        [-11.9],
#        [-22.7],
#        [ -9.5],
#        [-10.5],
#        [-11.2],
#        [  3.6],
#        [ -4.1],
#        [ 14.8],
#        [ 36.6],
#        [ 13.7],
#        [ 33.6],
#        [ -0.7],
#        [-30.1],
#        [ 22.9],
#        [ 38.3],
#        [ 27.4],
#        [ 23.9],
#        [ 14.5],
#        [  8.8],
#        [ 22.6],
#        [ 39.2],
#        [ 43.3],
#        [-29.9],
#        [ 29.3],
#        [ 13.4],
#        [  8.9],
#        [ 12.8],
#        [ -6.4],
#        [ -2.9],
#        [  7.7],
#        [-19.5],
#        [ -2.7],
#        [ 20. ],
#        [ -1.6],
#        [-26.4],
#        [-17.2],
#        [ 26.7],
#        [ 17. ],
#        [ -2.5],
#        [  6.2],
#        [  2.8],
#        [ 12.3],
#        [ 30.7],
#        [  6.6],
#        [ 18. ],
#        [-33.7],
#        [  2.4],
#        [ 30.4],
#        [-18. ],
#        [  2.6],
#        [-30.6],
#        [  5.7],
#        [  3. ],
#        [ -2.3],
#        [  8.7],
#        [ 26.4],
#        [ -3.8],
#        [  1.2],
#        [ 21.7],
#        [  7.7],
#        [ 16.5],
#        [ 42.4],
#        [  3.5],
#        [ -7.3],
#        [ -8.8],
#        [  3.9],
#        [-10.9],
#        [-20. ],
#        [ 19.9],
#        [ 34.7],
#        [-32.5],
#        [ 20.8],
#        [  5.8],
#        [ 26.7],
#        [ 42.4],
#        [ 36. ],
#        [  8.2],
#        [-17.5],
#        [-16.7],
#        [ 20.7],
#        [  5.4],
#        [ -9.7],
#        [  3.6],
#        [ 26. ],
#        [ -5.5],
#        [ -2.7],
#        [ 29.4],
#        [ 18.4],
#        [-25.4],
#        [-39.1],
#        [  8.5],
#        [-10.9],
#        [ -0.7],
#        [-19.6],
#        [ -8.5],
#        [ 31.6],
#        [-16. ],
#        [ 17. ],
#        [ 14.6],
#        [  1.8],
#        [ 37.8],
#        [ -4.7],
#        [ 26.9],
#        [ -1.3],
#        [ 20.9],
#        [ 36.1],
#        [-29.6],
#        [ 20.7],
#        [ -3.9],
#        [ 25.4],
#        [ 16.1],
#        [ 16. ],
#        [-31.3],
#        [-37.5],
#        [ -5.6],
#        [-11.1],
#        [ 13.5],
#        [-15.9],
#        [ -8.9],
#        [ -1.3],
#        [ -6.3],
#        [ 23.6],
#        [ 16. ],
#        [-17.5],
#        [ 13.1],
#        [ 20.4],
#        [-22.8],
#        [ -4.8],
#        [-13.5],
#        [ -6.7],
#        [ 29.1],
#        [ 40.6],
#        [ 35.5],
#        [ 36.5],
#        [ 28.2],
#        [ 47.4],
#        [ 28.3],
#        [ -9.2],
#        [-11.6],
#        [ 32.1],
#        [-21.1],
#        [-19. ],
#        [-29.3],
#        [ 18. ],
#        [  3.8],
#        [  3.8],
#        [ -0.8],
#        [ 17.3],
#        [-23.7],
#        [  9.6],
#        [ 32.1],
#        [ 23. ],
#        [ 25.9],
#        [  7.4],
#        [  6.2],
#        [  8.3],
#        [-38.7],
#        [ -7.7],
#        [ 20.2],
#        [ 37.9],
#        [-30.5],
#        [ 16. ],
#        [  3.8],
#        [  6.6],
#        [ 45.1],
#        [ 15.3],
#        [ 21.3],
#        [ 25.1],
#        [  6.8],
#        [-10.8],
#        [  4.7],
#        [ 17.8],
#        [ 30.3],
#        [  1.3],
#        [ -2. ],
#        [ 46.6],
#        [ 27.2],
#        [-26.1],
#        [-11.9],
#        [ -7.8],
#        [ 15.9],
#        [ 30.2],
#        [ -5.3],
#        [-29.5],
#        [ -1.3],
#        [-18.9],
#        [ -2.4],
#        [-33. ],
#        [-18.1],
#        [-10.4],
#        [ -9.4],
#        [-18.2],
#        [ 24.4],
#        [  4.3],
#        [-15.9],
#        [-14.6],
#        [ -3.3],
#        [-28.5],
#        [ 13.3],
#        [ -5. ],
#        [ 22.8],
#        [-15.3],
#        [ 21.9],
#        [ 19.7],
#        [  8.4],
#        [ 39.3],
#        [-18.8],
#        [ 35. ],
#        [-37.1],
#        [ 21. ],
#        [-14.4],
#        [  0.2],
#        [  2. ],
#        [ 45.8],
#        [ 43.3],
#        [ 18.4],
#        [-21.6],
#        [ 25.5],
#        [ 18.3],
#        [  8.9],
#        [ 15.5],
#        [ -6.9],
#        [ -3.3],
#        [  5.2],
#        [ 37.6],
#        [ 38. ],
#        [-32.7],
#        [ 19.5],
#        [ 37.8],
#        [-23.5],
#        [ 33.7],
#        [ -8.2],
#        [ 23.7],
#        [ 19. ],
#        [-28.4],
#        [  7.9],
#        [-20.7],
#        [ 23. ],
#        [  6.8],
#        [-17.4],
#        [ 20.4],
#        [-25.1],
#        [-15.7],
#        [ 26.3],
#        [-24.5],
#        [ 25.2],
#        [ 14.3],
#        [ 42. ],
#        [-30.1],
#        [ -3. ],
#        [-20.7],
#        [ 35.9],
#        [ 12.5],
#        [ -4.6],
#        [-13.3],
#        [-15.7],
#        [ 14.4],
#        [  0.1],
#        [ -3.7],
#        [ 23.3],
#        [ 14.6],
#        [ 37.4],
#        [  9.6],
#        [ 24. ],
#        [  6.1],
#        [ 26.3],
#        [  6.3],
#        [ 17.5],
#        [ -4.6],
#        [  1.6],
#        [  1.8],
#        [ 14. ],
#        [ 46.1],
#        [ -9.9],
#        [-18. ],
#        [ 32.1],
#        [ -0.3],
#        [-11.4],
#        [ 18.4],
#        [-22.6],
#        [  2.1],
#        [  0.5],
#        [  2.7],
#        [ -7. ],
#        [ 13.3],
#        [ 17.3],
#        [-31.8],
#        [ 17.3],
#        [ 36.8],
#        [ -0. ],
#        [ 43.6],
#        [ 13.8],
#        [-19.5],
#        [ 30.4],
#        [ -8.5],
#        [  7.4],
#        [ 37.5],
#        [ 18.3],
#        [-27.7],
#        [ -0.6],
#        [  5.4],
#        [ 19.3],
#        [ -2.8],
#        [-38.3],
#        [-31. ],
#        [ 30.9],
#        [ -6.8],
#        [ 10.2],
#        [ 27.9],
#        [ 23.6],
#        [  7. ],
#        [  6.8],
#        [-24.1],
#        [ 39.1],
#        [ 43. ],
#        [ 24. ],
#        [ 26.6],
#        [-38. ],
#        [ 16.4],
#        [-15.3],
#        [-18.9],
#        [ 19.9],
#        [ 22.4],
#        [  4.7],
#        [ 14.4],
#        [-20.3],
#        [ 16.9],
#        [ 29.5],
#        [ 31.3],
#        [  7.9],
#        [ -2.4],
#        [  0.1],
#        [ 33.4],
#        [ 20.4],
#        [ 10.5],
#        [ 31.5],
#        [ -1.5],
#        [ 28.3],
#        [ -9.1],
#        [ 16.5],
#        [ -6.2],
#        [  7.5],
#        [  1.4],
#        [ 34. ],
#        [ 23.4],
#        [-13.3],
#        [ 10.5],
#        [ 10.7],
#        [  4.8],
#        [-10.3],
#        [ -5.4],
#        [ 26.1],
#        [-11.6],
#        [ 12.7],
#        [ 29.8],
#        [ 45.4],
#        [  9.4],
#        [ 46.2],
#        [ 14.1],
#        [  0.4],
#        [ 12.1],
#        [  6.7],
#        [-17.8],
#        [ -9.2],
#        [ 27. ],
#        [ -6. ],
#        [ -1.9],
#        [ 19.7],
#        [ 14.1],
#        [ 14.3],
#        [ 22.3],
#        [ 40.9],
#        [ 17.6],
#        [ 10.4],
#        [  3. ],
#        [ 17.6],
#        [ -7.1],
#        [ -9.2],
#        [ -7.4],
#        [  6.3],
#        [ 35.7],
#        [ 23.1],
#        [ 41.1],
#        [ 34.6],
#        [-12.2],
#        [ 18.7],
#        [ 41.6],
#        [ 35.7],
#        [-11.4],
#        [ -6.6],
#        [ 19.7],
#        [ 34.8],
#        [  7.6],
#        [  9.7],
#        [ 25.2],
#        [  2.8],
#        [ 13.8],
#        [-24.5],
#        [ -4.7],
#        [-29.6],
#        [ 29.8],
#        [ 29.5],
#        [-25.3],
#        [  1.1],
#        [  9.2],
#        [ -8.2],
#        [ 15.8],
#        [  6.9],
#        [ -1.2],
#        [ 17.2],
#        [ -2.3],
#        [-13.7],
#        [ 22.4],
#        [ 10.2],
#        [ 21.1],
#        [ 22.2],
#        [ -4.3],
#        [  7.9],
#        [ 22.8],
#        [  4.9],
#        [ 28.7],
#        [-18.8],
#        [  1.6],
#        [ 39.9]])

# %% [markdown]
# ## 散布図の作成

# %%
# 散布図を表示していきます
plt.plot(np.squeeze(model.predict_on_batch(training_data['inputs'])), np.squeeze(training_data['targets']))
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bcf5470e9a89> in <module>
#       1 # 散布図を表示していきます
# ----> 2 plt.plot(np.squeeze(model.predict_on_batch(training_data['inputs'])), np.squeeze(training_data['targets']))
#       3 plt.xlabel('outputs')
#       4 plt.ylabel('targets')
#       5 plt.show()
#
# NameError: name 'plt' is not defined
